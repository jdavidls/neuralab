# %%
from neuralab.trading import Dataset
from neuralab.trading.knowledge import MARKETSET_BINANCE, SYMBOLSET_TWO_BIGS
from neuralab.utils.timeutils import TimeRange

dataset = Dataset.Ref(TimeRange.of('2024 1m'), SYMBOLSET_TWO_BIGS, MARKETSET_BINANCE).fetch()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from einops import rearrange
from matplotlib import pyplot as plt

plt.pcolormesh(rearrange(dataset.hard_logits[0:1000], 't a m -> (a m) t'))

# %%
trends = dataset.trends
trends.
# Out:
# (53021,)
